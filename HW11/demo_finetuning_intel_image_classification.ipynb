# %%
# %matplotlib inline

# %% [markdown]
# # Finetuning Torchvision Models

# %% [markdown]
# Transfer learning:
# - https://cs231n.github.io/transfer-learning/
# - https://ruder.io/transfer-learning/
# - https://pytorch.org/tutorials/beginner/finetuning_torchvision_models_tutorial.html
# - https://pytorch.org/tutorials/beginner/transfer_learning_tutorial.html
# - https://pytorch.org/vision/stable/models.html
# - https://pytorch.org/tutorials/beginner/basics/data_tutorial.html
# - https://pytorch.org/vision/stable/transforms.html
#
# Transfer learning methods follow the same few steps:
#
# -  Initialize the pretrained model
# -  Reshape the final layer(s) to have the same number of outputs as the number of classes in the new dataset
# -  Define for the optimization algorithm which parameters we want to update during training
# -  Run the training step

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset
import numpy as np
import torchvision
from torchvision.io import read_image
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy
from pathlib import Path
from typing import Dict, List, Text, Optional, Tuple
from PIL import Image
print("PyTorch Version: ",torch.__version__)
print("Torchvision Version: ",torchvision.__version__)
# Out:
# PyTorch Version:  2.0.1+cu118
# Torchvision Version:  0.15.2+cu118

# %%
from google.colab import drive
import os.path
drive.mount('/content/gdrive', force_remount=True)
data_set_path = '/content/gdrive/MyDrive/ML/HW07/FInal'
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## Inputs
#
# ### Data Set
#
# #### Intel Image Classification
#
# Dataset: https://www.kaggle.com/datasets/puneet6060/intel-image-classification
#
# ### Available models
# - resnet
# - alexnet
# - vgg
# - squeezenet
# - densenet
# - inception
# - mobilenet
# - efficientnet
#
# See: https://pytorch.org/vision/stable/models.html

# %%
train_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.RandomHorizontalFlip(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

test_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# %%
train_dataset = torchvision.datasets.ImageFolder(root=data_set_path + '/Train', transform=train_transform)
test_dataset = torchvision.datasets.ImageFolder(root=data_set_path + '/Test', transform=test_transform)

# %%
fig = plt.figure(figsize=(10, 10))
visualize_dataset = torchvision.datasets.ImageFolder(root=data_set_path + '/Train')
rows, columns = 5, 5
rand_indeces = np.random.randint(low=0, high=len(visualize_dataset), size=(rows*columns,))

images = []
labels = []

for i in rand_indeces:
    img, class_ = visualize_dataset[i]
    images.append(img)
    labels.append(visualize_dataset.classes[class_])

# visualize these random images
for i in range(1, columns*rows +1):
    fig.add_subplot(rows, columns, i)
    plt.imshow(images[i-1])
    plt.xticks([])
    plt.yticks([])
    plt.title(f"{labels[i-1]}")

# %%
from torchvision.models import ResNet18_Weights

# Number of classes in the dataset
num_classes = len(train_dataset.classes)

# Batch size for training (change depending on how much memory you have)
batch_size = 350

# Number of epochs to train for
num_epochs = 50

# Device for running training
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Models to choose from [resnet, alexnet, vgg, squeezenet, densenet, inception]
# model = models.resnet18(pretrained=True)
model = models.resnet18(weights=ResNet18_Weights.IMAGENET1K_V1)

# Training only the last layer, the other layers are freezed
for param in model.parameters():
    param.requires_grad = False

num_ftrs = model.fc.in_features

model.fc = nn.Linear(num_ftrs, num_classes, bias=True)
print(f"{num_ftrs = }")
# Out:
# num_ftrs = 512

# %% [markdown]
# ## Helper Functions

# %%
def train_model(model, dataloaders, criterion, optimizer, num_epochs=25):
    since = time.time()

    train_acc_history = []
    train_loss_history = []

    val_acc_history = []
    val_loss_history = []

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    y_pred_proba = torch.softmax(outputs, dim=1)
                    y_pred = y_pred_proba.argmax(dim=1)
                    # print(f"{y_pred = }")
                    # print(f"{labels = }")
                    # print(f"{y_pred.shape = }")
                    # print(f"{labels.shape = }")
                    # loss = criterion(y_pred_proba, labels)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                # print(f"{preds = }")
                # print(f"{labels.data = }")
                running_corrects += torch.sum(y_pred == labels)

            epoch_loss = running_loss / len(dataloaders[phase].dataset)
            epoch_acc = running_corrects.double() / len(dataloaders[phase].dataset)

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
            if phase == 'val':
                val_acc_history.append(epoch_acc)
                val_loss_history.append(epoch_loss)
            if phase == 'train':
                train_acc_history.append(epoch_acc)
                train_loss_history.append(epoch_loss)

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model, val_acc_history, val_loss_history, train_acc_history, train_loss_history

# %% [markdown]
# ## Load Data

# %%
# Create training and validation datasets

train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=4)
test_dataloader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=4)

# Create training and validation dataloaders
dataloaders_dict = {
    "train": train_dataloader,
    "val": test_dataloader,
}
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %% [markdown]
# ## Create the Optimizer

# %%
# Send the model to GPU
model = model.to(device)

# Observe that all parameters are being optimized
# optimizer_ft = optim.SGD(params_to_update, lr=0.001, momentum=0.9)
# optimizer_ft = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)
optimizer_ft = optim.Adam(params=model.parameters())

# %% [markdown]
# ## Run Training and Validation Step

# %%
# Setup the loss fxn
criterion = nn.CrossEntropyLoss()

# Train and evaluate
model_ft, val_acc_history, val_loss_history, train_acc_history, train_loss_history = train_model(model, dataloaders_dict, criterion, optimizer_ft, num_epochs=num_epochs)
# Out:
# Epoch 0/49
# ----------
# train Loss: 1.1705 Acc: 0.3596
# val Loss: 1.0928 Acc: 0.4043
#
# Epoch 1/49
# ----------
# train Loss: 1.0994 Acc: 0.4037
# val Loss: 1.0480 Acc: 0.4418
#
# Epoch 2/49
# ----------
# train Loss: 1.0373 Acc: 0.4557
# val Loss: 1.0322 Acc: 0.4956
#
# Epoch 3/49
# ----------
# train Loss: 0.9950 Acc: 0.5213
# val Loss: 1.0112 Acc: 0.4793
#
# Epoch 4/49
# ----------
# train Loss: 0.9701 Acc: 0.5241
# val Loss: 0.9852 Acc: 0.5269
#
# Epoch 5/49
# ----------
# train Loss: 0.9548 Acc: 0.5537
# val Loss: 0.9675 Acc: 0.5307
#
# Epoch 6/49
# ----------
# train Loss: 0.9297 Acc: 0.5692
# val Loss: 0.9552 Acc: 0.5407
#
# Epoch 7/49
# ----------
# train Loss: 0.9076 Acc: 0.5785
# val Loss: 0.9472 Acc: 0.5532
#
# Epoch 8/49
# ----------
# train Loss: 0.8980 Acc: 0.5884
# val Loss: 0.9387 Acc: 0.5519
#
# Epoch 9/49
# ----------
# train Loss: 0.8891 Acc: 0.5959
# val Loss: 0.9299 Acc: 0.5582
#
# Epoch 10/49
# ----------
# train Loss: 0.8738 Acc: 0.6142
# val Loss: 0.9257 Acc: 0.5544
#
# Epoch 11/49
# ----------
# train Loss: 0.8644 Acc: 0.6165
# val Loss: 0.9222 Acc: 0.5582
#
# Epoch 12/49
# ----------
# train Loss: 0.8568 Acc: 0.6263
# val Loss: 0.9197 Acc: 0.5632
#
# Epoch 13/49
# ----------
# train Loss: 0.8659 Acc: 0.6123
# val Loss: 0.9279 Acc: 0.5607
#
# Epoch 14/49
# ----------
# train Loss: 0.8609 Acc: 0.6020
# val Loss: 0.9190 Acc: 0.5757
#
# Epoch 15/49
# ----------
# train Loss: 0.8466 Acc: 0.6193
# val Loss: 0.9169 Acc: 0.5594
#
# Epoch 16/49
# ----------
# train Loss: 0.8492 Acc: 0.6076
# val Loss: 0.9144 Acc: 0.5795
#
# Epoch 17/49
# ----------
# train Loss: 0.8446 Acc: 0.6188
# val Loss: 0.9070 Acc: 0.5707
#
# Epoch 18/49
# ----------
# train Loss: 0.8364 Acc: 0.6259
# val Loss: 0.9075 Acc: 0.5632
#
# Epoch 19/49
# ----------
# train Loss: 0.8311 Acc: 0.6343
# val Loss: 0.9086 Acc: 0.5645
#
# Epoch 20/49
# ----------
# train Loss: 0.8196 Acc: 0.6273
# val Loss: 0.9149 Acc: 0.5645
#
# Epoch 21/49
# ----------
# train Loss: 0.8343 Acc: 0.6329
# val Loss: 0.9185 Acc: 0.5770
#
# Epoch 22/49
# ----------
# train Loss: 0.8310 Acc: 0.6212
# val Loss: 0.9063 Acc: 0.5757
#
# Epoch 23/49
# ----------
# train Loss: 0.7982 Acc: 0.6582
# val Loss: 0.9066 Acc: 0.5770
#
# Epoch 24/49
# ----------
# train Loss: 0.8054 Acc: 0.6409
# val Loss: 0.9058 Acc: 0.5770
#
# Epoch 25/49
# ----------
# train Loss: 0.7981 Acc: 0.6517
# val Loss: 0.9071 Acc: 0.5670
#
# Epoch 26/49
# ----------
# train Loss: 0.8033 Acc: 0.6367
# val Loss: 0.9051 Acc: 0.5820
#
# Epoch 27/49
# ----------
# train Loss: 0.7878 Acc: 0.6545
# val Loss: 0.9038 Acc: 0.5782
#
# Epoch 28/49
# ----------
# train Loss: 0.7901 Acc: 0.6545
# val Loss: 0.9053 Acc: 0.5782
#
# Epoch 29/49
# ----------
# train Loss: 0.7876 Acc: 0.6460
# val Loss: 0.9040 Acc: 0.5857
#
# Epoch 30/49
# ----------
# train Loss: 0.7797 Acc: 0.6634
# val Loss: 0.9075 Acc: 0.5770
#
# Epoch 31/49
# ----------
# train Loss: 0.7860 Acc: 0.6521
# val Loss: 0.9059 Acc: 0.5882
#
# Epoch 32/49
# ----------
# train Loss: 0.7911 Acc: 0.6587
# val Loss: 0.9049 Acc: 0.5857
#
# Epoch 33/49
# ----------
# train Loss: 0.7802 Acc: 0.6517
# val Loss: 0.9065 Acc: 0.5882
#
# Epoch 34/49
# ----------
# train Loss: 0.7773 Acc: 0.6657
# val Loss: 0.9082 Acc: 0.5745
#
# Epoch 35/49
# ----------
# train Loss: 0.7790 Acc: 0.6474
# val Loss: 0.9061 Acc: 0.5832
#
# Epoch 36/49
# ----------
# train Loss: 0.7695 Acc: 0.6699
# val Loss: 0.9047 Acc: 0.5820
#
# Epoch 37/49
# ----------
# train Loss: 0.7688 Acc: 0.6629
# val Loss: 0.9068 Acc: 0.5882
#
# Epoch 38/49
# ----------
# train Loss: 0.7645 Acc: 0.6704
# val Loss: 0.9039 Acc: 0.5845
#
# Epoch 39/49
# ----------
# train Loss: 0.7636 Acc: 0.6643
# val Loss: 0.9026 Acc: 0.5857
#
# Epoch 40/49
# ----------
# train Loss: 0.7627 Acc: 0.6657
# val Loss: 0.9040 Acc: 0.5907
#
# Epoch 41/49
# ----------
# train Loss: 0.7570 Acc: 0.6714
# val Loss: 0.9022 Acc: 0.5882
#
# Epoch 42/49
# ----------
# train Loss: 0.7666 Acc: 0.6629
# val Loss: 0.9042 Acc: 0.5882
#
# Epoch 43/49
# ----------
# train Loss: 0.7570 Acc: 0.6699
# val Loss: 0.9028 Acc: 0.5857
#
# Epoch 44/49
# ----------
# train Loss: 0.7543 Acc: 0.6779
# val Loss: 0.9045 Acc: 0.5907
#
# Epoch 45/49
# ----------
# train Loss: 0.7562 Acc: 0.6690
# val Loss: 0.9025 Acc: 0.5870
#
# Epoch 46/49
# ----------
# train Loss: 0.7604 Acc: 0.6704
# val Loss: 0.9008 Acc: 0.5907
#
# Epoch 47/49
# ----------
# train Loss: 0.7485 Acc: 0.6803
# val Loss: 0.9061 Acc: 0.6045
#
# Epoch 48/49
# ----------
# train Loss: 0.7555 Acc: 0.6695
# val Loss: 0.9022 Acc: 0.5945
#
# Epoch 49/49
# ----------
# train Loss: 0.7432 Acc: 0.6760
# val Loss: 0.9087 Acc: 0.5957
#
# Training complete in 13m 48s
# Best val Acc: 0.604506

# %%
val_acc_history_cpu = [i.item() for i in val_acc_history]
val_loss_history_cpu = val_loss_history
train_acc_history_cpu = [i.item() for i in train_acc_history]
train_loss_history_cpu = train_loss_history

# %%
plt.plot(val_acc_history_cpu, label="val acc")
plt.plot(train_acc_history_cpu, label="train acc")
plt.xlabel("epoch")
plt.ylabel("accuracy")
plt.legend()

# %%
plt.plot(np.log(np.array(val_loss_history_cpu)), label="val loss")
plt.plot(np.log(np.array(train_loss_history_cpu)), label="train loss")
plt.xlabel("epoch")
plt.ylabel("loss")
plt.legend()
torch.save(model.state_dict(), data_set_path+"mydataset_50.pth")
